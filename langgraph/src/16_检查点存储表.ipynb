# %% [markdown]
# # 检查点存储表
# - checkpoints: 存储每个graph.invoke()产生的检查点快照,比如checkpoint_id, parent_checkpoint_id, checkpoint,metadata
# - checkpoints_writes: 存储每个检查点下各节点任务的通道写入记录（一个检查点通过对应多条记录）
# - checkpoint_blobs: 存储通道级别的大型二进制数据，以(thread_id, checkpoint_ns, channel, version)为维度，可跨检查点复用
# - checkpoint_migrations: 用于数据库表结构版本管理
